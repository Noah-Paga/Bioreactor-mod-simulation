# %%
from IPython.display import Image, display, HTML

# %% [markdown]
# <div style='background-color: white; color: black; font-family: serif;'>
#
# # Project-2: Enzyme Kinetics and Microbial Growth
# ## Bioreactor Modelling and Simulation
# ### March 2026
#
# **Noah Paganuzzi, Andrea Bonnefous, Anders Eggen, Arthur Humery, Alexandre Keller**
#
# </div>

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ## Introduction
#
# This project explores the complexity of enzyme regulation, inhibition in microbial systems, and the steady-state properties and dynamics of continuous bioreactors. Indeed, actual biochemical systems are often subjected to chemical inhibitors inducing varying equilibria, which induce change in the reaction flux and growth of the desired products.
#
# This project began with an analysis of enzyme inhibition. Using the Lineweaver-Burk double-reciprocal method, the kinetic behavior of various systems was investigated to determine the type of inhibition mechanism (competitive, non-competitive and mixed). In addition, the inhibition constant ($K_I$) for a given model was determined using a secondary plot analysis, providing a quantitative measurement of inhibition affinity.
#
# In the second part, the focus shifts to microbial growth inhibition caused by an un-dissociated acid (lactic acid). Thus, taking the inhibition of the *Streptococcus Cremoris* by lactic acid, the role of solution properties, specifically pH and $pK_a$ are analyzed to identify the un-dissociated acid as the toxic species. Different mathematical models, such as hyperbolic and linear inhibition models are compared to determine the best fit for the microbial growth as a function of acidification.
#
# The third exercise explores the reversibility of enzymatic reactions, specifically the reversible transformation of 3-phospho-D-glycerate (g3p) into 2-phospho-D-glycerate (g2p) in the glycolytic pathway. By applying a Quasi-Steady-State Approximation (QSSA) to the reversible Michaelis-Menten model, a rate law is derived, which incorporates product inhibition and thermodynamic equilibrium. This allows for a simulation of the evolution of the metabolite concentration as a function of time and an investigation into how the initial conditions, specifically initial product concentrations, influence the reaction velocity $v$.
#
# Finally, the project examines the production of yeast biomass in a continuous reactor, known as a chemostat. By using experimental data, the yeast's maximum growth rate ($\mu_{max}$) and its affinity for substrate ($K_s$) were measured, while also accounting for the "maintenance energy" (i.e the energy cells need to stay alive). Then, the impact of changing the dilution rate ($D$) on the system's stability was investigated. This allows to determine the specific point where the reactor "washes out" ($D_{max}$) (i.e the point where the cells are being evacuated or pumped out before they can grow). Importantly, the optimal dilution rate ($D_{opt}$) which maximizes the productivity of the cells was identified. Finally, by evaluating different values of $K_s$, the yeast's efficiency was analyzed, allowing for determination of the best range for running the reactor without losing the cell culture.
#
# </div>

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ---
# ## Exercise 1
#
# ### Derivation of the Lineweaver-Burk Equation
#
# The derivation begins with the Michaelis-Menten equation:
#
# $$v = \frac{V_{max}[S]}{K_m + [S]} \tag{1}$$
#
# To linearize this relation, we take the reciprocal of both sides:
#
# $$\frac{1}{v} = \frac{K_m + [S]}{V_{max}[S]} \tag{2}$$
#
# Next, by distributing the denominator across the terms in the numerator to separate the variables we arrive at the Lineweaver-Burk format:
#
# $$\frac{1}{v} = \frac{K_m}{V_{max}} \cdot \frac{1}{[S]} + \frac{1}{V_{max}} \tag{3}$$
#
# The key parameters from the Lineweaver-Burk plot are:
#
# $$\text{y-intercept} = \frac{1}{V_{max}} \quad \left(\text{when } \frac{1}{[S]} = 0\right)$$
#
# $$\text{x-intercept} = -\frac{1}{K_m} \quad \left(\text{when } \frac{1}{v} = 0\right)$$
#
# $$\text{Slope} = \frac{K_m}{V_{max}} \tag{4}$$
#
#
#
# </div>

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ### (a) - Double-Reciprocal Plotting of Inhibitor A and B
#
# Below are the Lineweaver-Burk plots comparing the kinetic behavior of the enzyme with and without inhibitors A and B.
#
# </div>

# %% [markdown]
# <table style="width:100%; border-collapse: collapse; border: none;">
#   <tr>
#     <td style="text-align: center; border: none; width: 50%;">
#       <b>(a) Inhibitor A</b><br>
#       <img src="Images/Exercise_1_Inhibitor A.png" alt="Inhibitor A Plot" style="width: 100%; max-width: 400px;">
#     </td>
#     <td style="text-align: center; border: none; width: 50%;">
#       <b>(b) Inhibitor B</b><br>
#       <img src="Images/Exercise_1_Inhibitor B.png" alt="Inhibitor B Plot" style="width: 100%; max-width: 400px;">
#     </td>
#   </tr>
# </table>

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# The data used to generate these Figures is given in Table 5 in the Appendix

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ### (b) - Determining the $K_m$ and $V_{max}$ values for Inhibitors A and B
#
# To determine the kinetic constants, a linear regression was applied to the reciprocal data for each system. From the resulting fitted lines, the specific slope ($\frac{K_m}{V_{max}}$) and y-intercept ($\frac{1}{V_{max}}$) were extracted.
#
# As derived in Equation 3, the maximal velocity was calculated as the reciprocal of the y-intercept. Once $V_{max}$ was known, the Michaelis constant was determined by multiplying the measured slope by the derived $V_{max}$ ($K_m = \text{Slope} \cdot V_{max}$). The results of these calculations are summarized in Table 1.
#
# **Table 1: Calculated Kinetic Constants for Inhibitors A and B.**
#
# | System | $V_{max}$ (mM/min) | $K_m$ (mM) | Slope (min) |
# |---|---|---|---|
# | No Inhibitor | 14.98 | 0.40 | 0.0266 |
# | Inhibitor A | 14.96 | 0.80 | 0.0533 |
# | Inhibitor B | 6.03 | 0.40 | 0.0668 |
#
# </div>

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ### (c) - Identification of Inhibition Types for Compounds A and B
#
# **Inhibitor A:** The regression (Figure 1a and Table 1) shows that while the slope more than doubles compared to the non-inhibited case, the y-intercept remained unchanged. Thus, $V_{max}$ remains constant and $K_m$ increases when inhibitor A is added to the enzymatic reaction. Since $V_{max}$ is constant, the inhibitor can be outmuscled by a high substrate concentration but makes it harder for the substrate to bind at lower concentrations. Because of this, it can be concluded that it is Competitive Inhibition.
#
# **Inhibitor B:** In this case, both the slope and the y-intercept increase when inhibitor B is added to the system. However, the ratio remained such that the calculated $K_m$ stayed constant at $0.40\,mM$. The results for Inhibitor B show a substantial decrease in $V_{max}$ with no observable change in $K_m$. This indicates non-competitive inhibition, where the inhibitor effectively lowers the concentration of active enzyme.
#
# </div>

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ### (d) - Lineweaver-Burk Analysis of Enzyme Kinetics at Varying Concentrations of Inhibitor I
#
# Below is the Lineweaver-Burk plot which compares the kinetic behavior of the enzyme at different concentrations of the inhibitor ($I$).
#
# </div>

# %% [markdown]
# ![Exercise_1_Inhibitor_I.png](attachment:Exercise_1_Inhibitor_I.png)

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# The data used to generate this plots is given in Table 6 in the Appendix.

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# From visual inspection of the Lineweaver-Burk the following observations can be made. First, all four lines intersect at a single point on the y-axis. This indicates that the y-intercept, $\frac{1}{V_{max}}$, is constant regardless of the inhibitor concentration. Since $V_{max}$ is unaffected but the slope increases as $[I]$ increases, it can be deduced that this is a case of competitive inhibition.
#
# The inhibitor constant $K_I$ is found using the relation between the slope of the competitive Lineweaver-Burk plot and the inhibitor concentration. The slope of the competitive reciprocal plot is given below:
#
# $$\frac{1}{v} = \frac{K_m}{V_{max}}\left(1 + \frac{[I]}{K_I}\right)\frac{1}{[S]} + \frac{1}{V_{max}} \quad \rightarrow \quad \text{Slope} = \frac{K_m}{V_{max}}\left(1 + \frac{[I]}{K_I}\right) \tag{5}$$
#
# The derivation of the modified Lineweaver-Burk equation 5, generated from the modified Michaelis-Menten equation, is illustrated in the Appendix under Exercise 1.
#
# By plotting the slopes derived from the Lineweaver-Burk plot against the corresponding inhibitor concentrations $[I]$, a linear relationship is obtained. This is shown in Figure 12 under Exercise 1 in the Appendix. From this secondary plot, the slope of the uninhibited enzyme ($\frac{K_m}{V_{max}}$) can be found as the y-intercept and $-K_I$ can be found as the x-intercept ($0 = 1 + \frac{[I]}{K_I} \rightarrow [I]_0 = -K_I$).
#
# Performing this linear regression on the slopes, the secondary plot gave an inhibition constant: $K_I = 0.665\,\text{mM}$. This value represents the dissociation constant for the enzyme-inhibitor complex $[EI]$. Thus the magnitude of $K_I$ gives an indication of the affinity of the inhibitor for the active site.
#
# </div>

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ---
# ## Exercise 2
#
# ### (a) Conversion to Undissociated Acid Concentration
#
# The inhibitory effect of lactic acid on *S. cremoris* is caused only by the undissociated form of the acid (HA), since it is the only form able to cross the cell membrane and disturb the internal pH of the cell. To find what fraction of the total acid is undissociated at a given pH, we use the Henderson–Hasselbalch equation (derivation in Appendix):
#
# $$f_{HA} = \frac{1}{1 + 10^{\text{pH} - pK_a}} \tag{6}$$
#
# At pH = 6.3 and $pK_a = 3.88$, this gives $f_{HA} = 3.787 \times 10^{-3}$, meaning only about 0.38% of the total acid is in its undissociated form. The undissociated concentration $P$ in mM is then computed as:
#
# $$P\,[\text{mM}] = f_{HA} \times \frac{p_{\text{total}}\,[\text{g}\,\text{L}^{-1}]}{M_w\,[\text{g}\,\text{mol}^{-1}]} \times 1000 \tag{7}$$
#
# where $M_w = 90.08\,\text{g}\,\text{mol}^{-1}$. The resulting $P$ values are given in Table 2.
#
# **Table 2: Undissociated lactic acid concentration $P$ at pH 6.3, $pK_a = 3.88$, $M_w = 90.08\,\text{g}\,\text{mol}^{-1}$.**
#
# | $p_{\text{total}}$ (g L⁻¹) | $P$ (mM) |
# |---|---|
# | 0.0 | 0.0000 |
# | 12.0 | 0.5046 |
# | 39.0 | 1.6398 |
# | 55.0 | 2.3125 |
#
# The relative specific growth rate $\mu/\mu_0$, where $\mu_0 = \mu(P=0) = 0.9\,\text{h}^{-1}$, is plotted against $P$ in the figure below. A clear decreasing trend is observed: as $P$ increases, growth is progressively inhibited, confirming that the undissociated form is the toxic species.
#
# </div>

# %% [markdown]
# ![part_a_mu_rel_vs_P.png](attachment:part_a_mu_rel_vs_P.png)

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ### (b) Model 1: Hyperbolic Inhibition
#
# The inhibition constant was estimated using a linearised form of the model and a linear regression (`polyfit`), giving: $K_I = 0.4565\,\text{mM}$. However, when evaluating the fit in terms of the original variable $\mu$, the agreement with the experimental data is poor, with a coefficient of determination $R^2 \approx 0.466$. This indicates that the model does not adequately describe the data when fitted using this approach.
#
# This discrepancy arises from the linearisation step, which distorts the error structure by fitting $1/\mu$ instead of $\mu$. As a result, the regression no longer minimises the error on the physically relevant variable, leading to a biased parameter estimate and a poor fit.
#
# The fitted curve confirms this observation, as it fails to accurately capture the intermediate data points. This suggests that either the model is not well suited to the dataset, or that the estimation method is not appropriate.
#
# </div>

# %% [markdown]
# ![part_b_model1_fit.png](attachment:part_b_model1_fit.png)

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ### (c) Model 2: Linear Inhibition and Model Comparison
#
# A second model assumes a linear decrease of the growth rate with $P$:
#
# $$\mu = \mu_{max}\left(1 - \frac{P}{P_{max}}\right) \tag{8}$$
#
# where $P_{max}$ is the concentration at which growth stops entirely ($\mu = 0$). With $\mu_{max} = 0.9\,\text{h}^{-1}$ fixed, $P_{max}$ is estimated by linear regression, giving:
#
# $$P_{max} = 2.9901\,\text{mM} \tag{9}$$
#
# To compare both models, we use the coefficient of determination $R^2$ and the root mean square error (see Appendix for equations). The results are summarised in Table 3.
#
# **Table 3: Quantitative comparison of the two inhibition models.**
#
# | Model | Expression | Parameter | $R^2$ | RMSE (h⁻¹) |
# |---|---|---|---|---|
# | Model 1 (hyperbolic) | $\frac{\mu_{max}}{1 + P/K_I}$ | $K_I = 0.4565\,\text{mM}$ | 0.46574 | 0.20560 |
# | Model 2 (linear) | $\mu_{max}\left(1 - \frac{P}{P_{max}}\right)$ | $P_{max} = 2.990\,\text{mM}$ | 0.928 | 0.075 |
#
# A comparison of the two models shows that Model 2 provides a significantly better fit, with $R^2 = 0.928$ and $\text{RMSE} = 0.075\,\text{h}^{-1}$, compared to $R^2 \approx 0.466$ and $\text{RMSE} = 0.206\,\text{h}^{-1}$ for Model 1. This difference is partly due to the limitations of the linearisation used in Model 1, which introduces a bias in parameter estimation. In contrast, Model 2 is fitted directly in terms of $\mu$, preserving the error structure and resulting in a more reliable regression. Additionally, the experimental data follow an approximately linear trend with $P$, which is well captured by Model 2. The hyperbolic model, on the other hand, decreases too rapidly at low $P$ and too slowly at higher values, failing to represent the intermediate region. Within the studied range, no clear saturation behaviour is observed, making the linear model a more appropriate description of the inhibition. Model 2 is therefore selected for the remainder of the analysis.
#
# </div>

# %% [markdown]
# ![part_c_model_comparison.png](attachment:part_c_model_comparison.png)

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ### (d) Effect of pH on Growth Rate
#
# Using Model 2, the relative growth rate can be written as a function of pH by substituting $P(\text{pH})$ into Equation 8:
#
# $$\frac{\mu}{\mu_{max}} = 1 - \frac{1}{P_{max}} \cdot \frac{p_{\text{total}}}{M_w \times 1000} \cdot \frac{1}{1 + 10^{\text{pH} - pK_a}} \tag{10}$$
#
# Growth stops when $P = P_{max}$, i.e. $\mu = 0$. The critical pH is derived analytically in the Appendix, and the results are given in Table 4.
#
# **Table 4: Critical pH below which growth of *S. cremoris* ceases, for two total lactic acid concentrations (Model 2, $P_{max} = 2.990\,\text{mM}$).**
#
# | $p_{\text{total}}$ (g L⁻¹) | pH at which growth stops |
# |---|---|
# | 1.0 | 4.31 |
# | 10.0 | 5.44 |
#
# </div>

# %% [markdown]
# ![part_d_mu_vs_pH.png](attachment:part_d_mu_vs_pH.png)

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# The figure above shows several things worth discussing. At high pH (above 7), the relative growth rate is close to 1 for both concentrations, meaning growth is essentially unaffected. This makes sense because at high pH, almost all of the lactic acid is dissociated, so $P$ is very small regardless of the total concentration.
#
# As pH decreases, the undissociated fraction increases, and $P$ starts to rise. The growth rate then drops, first gradually and then more sharply as $P$ approaches $P_{max}$. The difference between the two curves becomes clearly visible in the pH range 4–7: at $10\,\text{g}\,\text{L}^{-1}$, growth stops at pH 5.44 while at $1\,\text{g}\,\text{L}^{-1}$ growth only stops at pH 4.31, a much more acidic environment.
#
# This result has a direct practical relevance. In fact, it shows that in a lactic acid fermentation, as the bacteria produce more acid and the pH drops, the increasing concentration of undissociated lactic acid creates a self-inhibiting feedback loop. At high total acid concentrations (e.g $10\,\text{g}\,\text{L}^{-1}$), the culture can be inhibited at relatively moderate pH values, which means pH control becomes critical to maintain productivity. Maintaining a higher pH (for example by adding a base) keeps most of the acid in its dissociated, non-toxic form, and allows growth to continue even at high total acid concentrations.
#
# </div>

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ---
# ## Exercise 3
#
# ### Part (a): Mass Balance
#
# The reversible reaction given:
#
# $$E + S \underset{k_{1,b}}{\overset{k_{1,f}}{\rightleftharpoons}} ES \underset{k_{2,b}}{\overset{k_{2,f}}{\rightleftharpoons}} E + P \tag{11}$$
#
# The general mass balance for a species $i$ in a reactor is given by:
#
# $$\frac{dN_i}{dt} = \dot{N}_{i,in} - \dot{N}_{i,out} + \dot{N}_{i,gen} \tag{12}$$
#
# For a batch reactor, there is no inlet or outlet flow. Therefore the balance simplifies to:
#
# $$\frac{dN_i}{dt} = \dot{N}_{i,gen} \tag{13}$$
#
# Since the reaction takes place in a reactor with constant volume $V$, we can write:
#
# $$N_i = C_i V \tag{14}$$
#
# which leads to the following expression where $r_i$ is the net rate of formation of species $i$:
#
# $$\frac{dC_i}{dt} = r_i \tag{15}$$
#
# For the reversible reaction given, the elementary reaction rates are:
#
# $$v_{1,f} = k_{1,f}[E][S] \quad v_{1,b} = k_{1,b}[ES] \quad v_{2,f} = k_{2,f}[ES] \quad v_{2,b} = k_{2,b}[E][P] \tag{16}$$
#
# For the substrate $S$:
#
# $$\frac{d[S]}{dt} = -v_{1,f} + v_{1,b} \tag{17}$$
#
# $$\frac{d[S]}{dt} = -k_{1,f}[E][S] + k_{1,b}[ES] \tag{18}$$
#
# Following the same procedure, the mass balance for the enzyme–substrate $ES$, the product $P$ and the free enzyme $E$ is obtained:
#
# $$\frac{d[ES]}{dt} = k_{1,f}[E][S] - k_{1,b}[ES] - k_{2,f}[ES] + k_{2,b}[E][P] \tag{19}$$
#
# $$\frac{d[P]}{dt} = k_{2,f}[ES] - k_{2,b}[E][P] \tag{20}$$
#
# $$\frac{d[E]}{dt} = -k_{1,f}[E][S] + k_{1,b}[ES] + k_{2,f}[ES] - k_{2,b}[E][P] \tag{21}$$
#
# </div>

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ### Part (b): QSSA approximation and expression of [ES]
#
# In order to determine the concentration of the enzyme and substrate complex, the quasi–steady state approximation was applied to the mass balance of $ES$, assuming that $\frac{d[ES]}{dt} = 0$. By rearranging the mass balance equation and grouping the terms containing $[E]$ and $[ES]$, the following relation between the free enzyme concentration and the complex concentration is obtained:
#
# $$(k_{1,f}[S] + k_{2,b}[P])[E] = (k_{1,b} + k_{2,f})[ES] \tag{22}$$
#
# The total enzyme concentration is conserved such that $[E]_0 = [E] + [ES]$, which allows the free enzyme concentration to be written as $[E] = [E]_0 - [ES]$. Substituting this expression into the previous equation eliminates the free enzyme concentration. After rearranging the resulting expression and isolating the enzyme–substrate complex concentration, the following expression for $[ES]$ was obtained:
#
# $$[ES] = \frac{[E]_0\left(k_{1,f}[S] + k_{2,b}[P]\right)}{k_{1,b} + k_{2,f} + k_{1,f}[S] + k_{2,b}[P]} \tag{23}$$
#
# From the mass balance of the product $[P]$ as shown in Eq. (20) and substituting the expressions of $[ES]$ and $[E] = [E]_0 - [ES]$, the rate of formation of $[P]$ is given by:
#
# $$\frac{d[P]}{dt} = \frac{[E]_0\left(k_{1,f}k_{2,f}[S] - k_{1,b}k_{2,b}[P]\right)}{k_{1,b} + k_{2,f} + k_{1,f}[S] + k_{2,b}[P]} \tag{24}$$
#
# </div>

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ### Part (c): Reversible Michaelis–Menten rate expression
#
# Using the rate expression of the product derived in part b) shown in Eq. (24), the denominator can be factorized by $(k_{1,b} + k_{2,f})$ in order to rewrite the equation in the reversible Michaelis–Menten form. This gives:
#
# $$K_{m,S} = \frac{k_{1,b} + k_{2,f}}{k_{1,f}} \qquad K_{m,P} = \frac{k_{1,b} + k_{2,f}}{k_{2,b}} \qquad V_{max,f} = [E]_0 k_{2,f} \qquad V_{max,b} = [E]_0 k_{1,b} \tag{25}$$
#
# Therefore:
#
# $$v([S],[P]) = \frac{\dfrac{V_{max,f}[S]}{K_{m,S}} - \dfrac{V_{max,b}[P]}{K_{m,P}}}{1 + \dfrac{[S]}{K_{m,S}} + \dfrac{[P]}{K_{m,P}}} \tag{26}$$
#
# From the four parameters $V_{max,f}$, $V_{max,b}$, $K_{m,S}$ and $K_{m,P}$ alone, the four elementary rate constants cannot be determined because $V_{max,f}$ and $V_{max,b}$ depend on the products $[E]_0 k_{2,f}$ and $[E]_0 k_{1,b}$.
#
# If the total enzyme concentration $[E]_0$ is known, the elementary rate constants can be written as:
#
# $$k_{2,f} = \frac{V_{max,f}}{[E]_0} \qquad k_{1,b} = \frac{V_{max,b}}{[E]_0} \qquad k_{1,f} = \frac{k_{1,b} + k_{2,f}}{K_{m,S}} \qquad k_{2,b} = \frac{k_{1,b} + k_{2,f}}{K_{m,P}} \tag{27}$$
#
# </div>

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ### Part (d): Determination of kinetic constants and ODE simulation
#
# Using the expression of $K_{m,S}$ and $K_{m,P}$ derived in Question c, the missing elementary rate constants can be determined from the given data:
#
# $$k_{1,b} = 10\,\text{s}^{-1} \qquad k_{2,f} = 22\,\text{s}^{-1} \qquad K_{m,S} = 210\,\mu\text{M} \qquad K_{m,P} = 97\,\mu\text{M} \tag{28}$$
#
# Thus, the four elementary rate constants obtained are:
#
# $$k_{1,b} = 10\,\text{s}^{-1} \qquad k_{2,f} = 22\,\text{s}^{-1} \qquad k_{1,f} = 1.52 \times 10^5\,\text{L}\,\text{mol}^{-1}\text{s}^{-1} \qquad k_{2,b} = 3.30 \times 10^5\,\text{L}\,\text{mol}^{-1}\text{s}^{-1} \tag{29}$$
#
# From the enzyme–substrate concentration derived in Question b (23) and using the enzyme conservation $[E]_0 = [E] + [ES]$, the mass balances of the substrate (18) and the product (20) can be rewritten as:
#
# $$\frac{d[S]}{dt} = -k_{1,f}([E]_0 - [ES])[S] + k_{1,b}[ES] \tag{30}$$
#
# $$\frac{d[P]}{dt} = k_{2,f}[ES] - k_{2,b}([E]_0 - [ES])[P] \tag{31}$$
#
# The system is solved numerically on the interval $t \in [0, 5]\,\text{s}$ using the initial conditions:
#
# $$[S_0] = 1\,\text{mol}\,\text{L}^{-1} \qquad [E_0] = 0.1\,\text{mol}\,\text{L}^{-1} \qquad [P_0] = 0\,\text{mol}\,\text{L}^{-1} \tag{32}$$
#
# As shown in the plot 7a, the substrate concentration decreases rapidly while the product concentration increases due to the enzymatic conversion. As time progresses, the system approaches equilibrium and both concentrations stabilize around $0.5\,\text{mol}\,\text{L}^{-1}$. This reflects the reversibility of the reaction and the formation of an equilibrium during the reaction.
#
# </div>

# %% [markdown]
# #### Plot 7a : Plot of the substrate and product concentration as a function of time for initial condition (32)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ### Part (e): Effect of initial product concentration
#
# Using the following initial condition, we obtain the plot 7b:
#
# $$[S_0] = 1\,\text{mol}\,\text{L}^{-1} \qquad [E_0] = 0.1\,\text{mol}\,\text{L}^{-1} \qquad [P_0] = 1\,\text{mol}\,\text{L}^{-1} \tag{33}$$
#
# The plot is consistent with the reversible nature of the reaction. Since the initial product concentration is already high, the backward reaction is important from the beginning of the simulation. As a result, the forward conversion of substrate into product is strongly reduced, the substrate concentration decreases only slightly, while the product concentration slightly increases before reaching equilibrium. This behavior differs from the classical irreversible Michaelis–Menten model studied in the 1st Project Exercise 1, where the rate depends only on the substrate concentration. Here, the product concentration appears explicitly in the rate equation and opposes the forward reaction. To recover a behavior similar to the irreversible Michaelis–Menten case, the backward kinetic constant $k_{2,b}$ should be reduced to zero.
#
# </div>

# %% [markdown]
# #### Plot 7b : Plot of the substrate and product concentration as a function of time for initial condition (33)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ### Part (f) (Bonus): Effect of high product concentration and equilibrium analysis
#
# Using the following initial condition, we obtain the plot 7c:
#
# $$[S_0] = 1\,\text{mol}\,\text{L}^{-1} \qquad [E_0] = 0.1\,\text{mol}\,\text{L}^{-1} \qquad [P_0] = 3\,\text{mol}\,\text{L}^{-1} \tag{34}$$
#
# For a higher initial product concentration, the product does not increase. Instead, it decreases with time, while the substrate concentration increases. This behavior is once again consistent with the reversible nature of the reaction.
#
# The overall equilibrium constant of the reaction is given by:
#
# $$K_{eq} = \frac{k_{1,f} k_{2,f}}{k_{1,b} k_{2,b}} = 1.013 \tag{35}$$
#
# Initially, the mass-action ratio is:
#
# $$Q = \frac{[P]}{[S]} = 3 \tag{36}$$
#
# which is larger than the equilibrium constant $K_{eq}$. Therefore, the system is initially shifted toward the product side and evolves in the reverse direction in order to restore equilibrium. As a result, product is consumed and substrate is formed until the ratio $[P]/[S]$ approaches its equilibrium value.
#
# </div>

# %% [markdown]
# #### Plot 7c : Plot of the substrate and product concentration as a function of time for initial condition (34)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ---
# ## Exercise 4
#
# ### System Overview
#
# Steady-state chemostat data were collected for yeast growth on a carbon substrate with feed concentration $S_0 = 10\,\text{g/L}$ and excess dissolved oxygen. All modelling assumes Monod kinetics, a constant yield coefficient $Y_{X/S}$, and a linear maintenance term $m$ on substrate consumption:
#
# $$r_s = \frac{\mu X}{Y_{X/S}} + mX, \qquad \mu = \frac{\mu_{max} S}{K_s + S}$$
#
# </div>

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ### Part (a): Estimation of $\mu_{max}$ and $K_s$
#
# At steady state the chemostat imposes $\mu = D$, so the Monod equation becomes:
#
# $$D = \frac{\mu_{max} S}{K_s + S}$$
#
# The seven pre-washout data points ($D \leq 0.80\,\text{h}^{-1}$) were used for parameter estimation; the washout point ($D = 0.84\,\text{h}^{-1}$) is excluded because the culture is no longer at a viable steady state. Parameters were estimated using the Lineweaver-Burk linearization, obtained by taking the reciprocal of the Monod equation:
#
# $$\frac{1}{D} = \frac{K_s}{\mu_{max}} \cdot \frac{1}{S} + \frac{1}{\mu_{max}}$$
#
# A linear regression of $1/D$ against $1/S$ yields $\mu_{max}$ from the $y$-intercept and $K_s$ from the slope, giving:
#
# $$\mu_{max} = 2.298\,\text{h}^{-1}, \qquad K_s = 0.548\,\text{g/L}$$
#
# The resulting Monod curve and Lineweaver-Burk linearization are shown alongside the experimental data in Figure 8.
#
# </div>

# %%
# Figure 8: Left: Lineweaver–Burk double-reciprocal plot (1/D vs. 1/S) confirming the parameter estimates.
#           Right: Monod fit (μ vs. S) with experimental data. Orange point = washout region (excluded from fit).
# [Figure placeholder - insert Lineweaver-Burk and Monod fit plots here]

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ### Part (b): Estimation of $Y_{X/S}$ and Maintenance Coefficient $m$
#
# Dividing the steady-state substrate balance by the biomass concentration gives:
#
# $$\frac{D(S_0 - S)}{X} = \frac{D}{Y_{X/S}} + m$$
#
# which is linear in $D$. A straight-line regression of the left-hand side against $D$ yields a slope of $1/Y_{X/S}$ and an intercept of $m$ (Figure 9). The estimated values are:
#
# $$Y_{X/S} = 0.5185\,\text{g}_X\,\text{g}_S^{-1}, \qquad m = 0.0872\,\text{g}_S\,\text{g}_X^{-1}\,\text{h}^{-1}$$
#
# The yield is consistent with the typical aerobic range of 0.4–0.6 g/g reported for yeast on glucose. The small but positive maintenance coefficient indicates that a minor fraction of substrate is consumed for cell upkeep rather than growth.
#
# </div>

# %%
# Figure 9: Linear regression used to extract Y_X/S (slope) and m (intercept) from the steady-state substrate balance.
# [Figure placeholder - insert yield and maintenance estimation plot here]

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ### Part (c): Derivation and Calculation of $D_{max}$ and $D_{opt}$
#
# The derivation for both $D_{max}$ and $D_{opt}$ was done in detail in the appendix. The results for each derivation are given below:
#
# $$D_{max} = \frac{\mu_{max} S_0}{K_s + S_0} = 2.1787\,\text{h}^{-1}$$
#
# $$D_{opt} = \mu_{max}\left(1 - \sqrt{\frac{K_s}{K_s + S_0}}\right) = 1.7724\,\text{h}^{-1}$$
#
# </div>

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ### Part (d): Steady-State $X$ and $S$ as Functions of $D$ (with Maintenance)
#
# Including maintenance, the steady-state expressions become:
#
# $$S(D) = \frac{D K_s}{\mu_{max} - D}, \qquad X(D) = \frac{Y_{X/S}(S_0 - S)}{1 + mY_{X/S}/D}$$
#
# Figure 10 shows the model curves overlaid on the experimental data. Biomass concentration rises gradually with dilution rate before dropping sharply near washout, while substrate concentration remains very low until the culture approaches washout and then rises steeply towards $S_0 = 10\,\text{g/L}$. The model captures both trends well, the slight deviation at $D = 0.84\,\text{h}^{-1}$ reflects the onset of washout dynamics that the steady-state model cannot describe.
#
# </div>

# %%
# Figure 10: Steady-state biomass X (orange) and substrate S (blue) concentrations as functions of dilution rate D,
# with maintenance included.
# [Figure placeholder - insert substrate and biomass vs dilution rate plot here]

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ### Part (e): Productivity $D \cdot X$ and Effect of $K_s$
#
# Figure 11 shows the volumetric productivity $P = D \cdot X$ as a function of $D$ for five values of $K_s$ spanning $0.25\,K_s$ to $4\,K_s$ (maintenance included). In every case productivity rises, reaches a maximum, then falls to zero at washout.
#
# As $K_s$ increases, the peak productivity decreases and shifts to lower dilution rates because a larger $K_s$ means the organism saturates its growth capacity only at higher substrate concentrations, leaving less driving force for high dilution without washout. On the other hand, a lower $K_s$ (higher substrate affinity) allows near-maximal growth at very low $S$, sustaining high productivity over a broader range of $D$.
#
# </div>

# %%
# Figure 11: Volumetric productivity D·X vs. D for five K_s values.
# Bold curve = estimated K_s = 0.548 g/L. Increasing K_s reduces peak productivity and shifts D_opt to lower values.
# [Figure placeholder - insert productivity vs dilution rate for various K_s values here]

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ### Part (f): Maximum Productivity and Corresponding Dilution Rate
#
# Using the parameters estimated in parts (a) and (b) with maintenance included, the productivity curve was computed numerically and its maximum located. The result is:
#
# $$D_{opt}^{(f)} = 1.7811\,\text{h}^{-1}, \qquad P_{max} = 7.3064\,\text{g}\,\text{L}^{-1}\,\text{h}^{-1}$$
#
# These are the optimal operating conditions for biomass production in this chemostat: diluting at $D \approx 1.78\,\text{h}^{-1}$ maximizes throughput while keeping the culture below the washout point at $D_{max} = 2.1787\,\text{h}^{-1}$.
#
# </div>

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ### Part (g): Comparison of $D_{opt}$ from Parts (c) and (f)
#
# The two estimates of the optimal dilution rate are:
#
# $$D_{opt}^{(c)} = 1.7724\,\text{h}^{-1} \quad (\text{analytical, no maintenance}), \qquad D_{opt}^{(f)} = 1.7811\,\text{h}^{-1} \quad (\text{numerical, with maintenance})$$
#
# a difference of roughly 0.49%. The negligible shift when maintenance is included confirms that the maintenance coefficient $m = 0.0872\,\text{g}_S\,\text{g}_X^{-1}\,\text{h}^{-1}$ is small relative to the growth-associated substrate demand at these dilution rates, making it a minor but non-negligible correction in precise design calculations.
#
# </div>

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ---
# ## Appendix
#
# ### Exercise 1
#
# **Data used in part a, to generate Figures 1a and 1b:**
#
# **Table 5: Reaction rates ($v$) at varying substrate concentrations in the absence and presence of Inhibitors A and B.**
#
# | [S] (mM) | No Inhibitor (mM/min) | Inhibitor A (mM/min) | Inhibitor B (mM/min) |
# |---|---|---|---|
# | 0.2 | 5.0 | 3.0 | 2.0 |
# | 0.4 | 7.5 | 5.0 | 3.0 |
# | 0.8 | 10.0 | 7.5 | 4.0 |
# | 1.0 | 10.7 | 8.3 | 4.3 |
# | 2.0 | 12.5 | 10.7 | 5.0 |
# | 4.0 | 13.6 | 12.5 | 5.5 |
#
# **Data used in part b, to generate Figure 2:**
#
# **Table 6: Reaction velocities ($v$) at varying substrate and inhibitor concentrations.**
#
# | [S] (mM) | [I] = 1mM | [I] = 2mM | [I] = 3mM | [I] = 4mM |
# |---|---|---|---|---|
# | 0.1 | 1.09 | 0.74 | 0.52 | 0.42 |
# | 0.3 | 2.89 | 1.96 | 1.47 | 1.17 |
# | 0.7 | 5.24 | 3.89 | 3.01 | 2.51 |
# | 2.0 | 8.85 | 7.40 | 6.31 | 5.43 |
# | 4.0 | 10.89 | 9.82 | 8.76 | 8.07 |
# | 6.0 | 12.11 | 11.36 | 10.02 | 9.37 |
#
# </div>

# %% [markdown]
# - **Plot of the slope of the Lineweaver-Burk plots vs [I] to find the inhibitor constant $K_I$**
#
#
# ![Exercise_1_K_I_plot.png](attachment:Exercise_1_K_I_plot.png)

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# - **Derivation of the Modified Lineweaver-Burk Equation 5**
#
# The derivation of the Michaelis-Menten (MM) equation in presence of a competitive inhibitor I (modified MM equation) is shown below.
#
# The reaction mechanism is as follows:
# - **Substrate Binding:** $E + S \rightleftharpoons ES \xrightarrow{k_{cat}} E + P$
# - **Inhibitor Binding:** $E + I \rightleftharpoons EI$
#
# The dissociation constant for the inhibitor $K_I$ is defined as:
#
# $$K_I = \frac{[E][I]}{[EI]} \rightarrow [EI] = \frac{[E][I]}{K_I} \tag{37}$$
#
# Now we use the mass balance for the enzyme (conservation of the enzyme), which in this modified situation is given by:
#
# $$[E]_0 = [E] + [ES] + [EI] \tag{38}$$
#
# Substituting the expression for $[EI]$ from Equation 37 into the mass balance:
#
# $$[E]_0 = [E] + [ES] + \frac{[E][I]}{K_I} = [E]\left(1 + \frac{[I]}{K_I}\right) + [ES] \tag{39}$$
#
# By defining the degree of inhibition as $\alpha = 1 + \frac{[I]}{K_I}$, we can isolate the enzyme $[E]$ and find:
#
# $$[E]_0 = [E]\alpha + [ES] \Rightarrow [E] = \frac{[E]_0 - [ES]}{\alpha} \tag{40}$$
#
# Next, by substituting the expression for E derived in Equation 40 into the standard definition of the Michaelis constant, $K_m = \frac{[E][S]}{[ES]}$:
#
# $$K_m = \frac{\left(\frac{[E]_0 - [ES]}{\alpha}\right)[S]}{[ES]} \tag{41}$$
#
# The concentration of the enzyme-substrate complex can now be found:
#
# $$[ES] = \frac{[E]_0[S]}{K_m\alpha + [S]} \tag{42}$$
#
# The reaction rate is defined as $v = k_{cat}[ES]$ and maximum velocity as $V_{max} = k_{cat}[E]_0$. Multiplying Equation 42 by $k_{cat}$ yields the modified Michaelis-Menten equation:
#
# $$v = \frac{V_{max}[S]}{K_m\alpha + [S]} \tag{43}$$
#
# Substituting the definition of $\alpha$ back into the equation gives the final form for competitive inhibition:
#
# $$v = \frac{V_{max}[S]}{K_m\left(1 + \frac{[I]}{K_I}\right) + [S]} \tag{44}$$
#
# Finally to derive the Lineweaver-Burk equation 5 shown in Exercise 1, part d, we take the reciprocal of both sides of the modified MM equation:
#
# $$\frac{1}{v} = \underbrace{\frac{K_m}{V_{max}}\left(1 + \frac{[I]}{K_I}\right)}_{\text{Slope}} \cdot \frac{1}{[S]} + \underbrace{\frac{1}{V_{max}}}_{\text{y-intercept}} \tag{45}$$
#
# </div>

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ### Exercise 2
#
# #### Conversion to Undissociated Acid Concentration
#
# The inhibitory effect of lactic acid is due to its undissociated form (HA), which is able to diffuse through the cell membrane. The relationship between the dissociated and undissociated forms is described by the Henderson–Hasselbalch equation:
#
# $$\text{pH} = pK_a + \log\left(\frac{[A^-]}{[HA]}\right) \tag{46}$$
#
# Rearranging this equation gives:
#
# $$\frac{[A^-]}{[HA]} = 10^{\text{pH} - pK_a} \tag{47}$$
#
# The fraction of undissociated acid is defined as:
#
# $$f_{HA} = \frac{[HA]}{[HA] + [A^-]} \tag{48}$$
#
# Substituting the ratio yields:
#
# $$f_{HA} = \frac{1}{1 + 10^{\text{pH} - pK_a}} \tag{49}$$
#
# The undissociated acid concentration $P$ (in mM) is obtained from the total lactic acid concentration:
#
# $$P = f_{HA} \cdot \frac{p_{\text{total}}}{M_w} \cdot 1000 \tag{50}$$
#
# where $M_w$ is the molar mass of lactic acid.
#
# #### Model 1: Hyperbolic Inhibition
#
# The inhibition model is expressed as:
#
# $$\mu = \frac{\mu_{max}}{1 + P/K_I} \tag{51}$$
#
# This equation is nonlinear with respect to the parameter $K_I$. To allow the use of linear regression, it is transformed by taking the reciprocal:
#
# $$\frac{1}{\mu} = \frac{1}{\mu_{max}} + \frac{P}{\mu_{max} K_I} \tag{52}$$
#
# This expression has the form of a linear equation $y = a + bx$ with:
#
# $$y = \frac{1}{\mu}, \quad x = P, \quad a = \frac{1}{\mu_{max}}, \quad b = \frac{1}{\mu_{max} K_I} \tag{54}$$
#
# A linear regression is therefore performed on $1/\mu$ as a function of $P$ using polyfit. Once the slope $b$ is obtained, the inhibition constant is calculated as:
#
# $$K_I = \frac{1}{b\,\mu_{max}} \tag{55}$$
#
# It should be noted that this linearisation modifies the distribution of experimental errors, since the regression is performed on $1/\mu$ instead of $\mu$.
#
# #### Model 2: Linear Inhibition
#
# The second model assumes a linear decrease of the growth rate with inhibitor concentration:
#
# $$\mu = \mu_{max}\left(1 - \frac{P}{P_{max}}\right) \tag{56}$$
#
# In this case, $P_{max}$ represents the concentration at which growth stops ($\mu = 0$). This model is directly linear in $\mu$, which allows parameter estimation without any transformation.
#
# #### Effect of pH on Growth Rate
#
# The undissociated acid concentration depends on pH according to:
#
# $$P = \frac{p_{\text{total}}}{M_w \cdot 1000} \cdot \frac{1}{1 + 10^{\text{pH} - pK_a}} \tag{57}$$
#
# Growth stops when $\mu = 0$, which corresponds to $P = P_{max}$. Substituting and solving for pH gives:
#
# $$\text{pH} = pK_a + \log\left(\frac{p_{\text{total}}}{M_w \cdot 1000 \cdot P_{max}} - 1\right) \tag{59}$$
#
# This expression allows the determination of the critical pH below which growth ceases for a given total lactic acid concentration.
#
# </div>

# %% [markdown]
# <div style='background-color: white; color: black;'>
#
# ### Exercise 4
#
# #### Part (c): Derivation of $D_{max}$ and $D_{opt}$
#
# **Derivation of $D_{max}$**
#
# At steady state, the chemostat biomass balance with sterile feed ($X_0 = 0$) gives $\mu = D$. Substituting the Monod equation and solving for the steady-state substrate concentration $S$:
#
# $$D(K_s + S) = \mu_{max} S \Rightarrow D K_s = (\mu_{max} - D) S \Rightarrow S(D) = \frac{D K_s}{\mu_{max} - D}$$
#
# As $D$ increases, $S$ increases monotonically. Washout occurs when the substrate concentration inside the reactor reaches the feed concentration ($S \rightarrow S_0$), meaning no substrate is being consumed because there is no viable biomass left. Setting $S = S_0$:
#
# $$S_0 = \frac{D_{max} K_s}{\mu_{max} - D_{max}} \Rightarrow S_0(\mu_{max} - D_{max}) = D_{max} K_s \Rightarrow S_0 \mu_{max} = D_{max}(K_s + S_0)$$
#
# $$D_{max} = \frac{\mu_{max} S_0}{K_s + S_0} = 2.1787\,\text{h}^{-1}$$
#
# **Derivation of $D_{opt}$**
#
# **Step 1:** Write $X(D)$ explicitly (ignoring maintenance, $m = 0$). The steady-state substrate balance simplifies to:
#
# $$D(S_0 - S) = \frac{DX}{Y_{X/S}} \Rightarrow X = Y_{X/S}(S_0 - S)$$
#
# Substituting $S(D)$ from above:
#
# $$X(D) = Y_{X/S}\left(S_0 - \frac{D K_s}{\mu_{max} - D}\right) = Y_{X/S} \cdot \frac{\mu_{max} S_0 - D(K_s + S_0)}{\mu_{max} - D}$$
#
# **Step 2:** Form the productivity $P = D \cdot X$. Let $A = \mu_{max} S_0$ and $B = K_s + S_0$ for brevity:
#
# $$P(D) = D \cdot X(D) = Y_{X/S} \cdot \frac{D(A - BD)}{\mu_{max} - D}$$
#
# **Step 3:** Differentiate and set to zero. Applying the quotient rule and setting $f'(D) = 0$ requires the numerator to vanish:
#
# $$(A - 2BD)(\mu_{max} - D) + D(A - BD) = 0$$
#
# Expanding and simplifying:
#
# $$A\mu_{max} - 2BD\mu_{max} + BD^2 = 0$$
#
# Dividing through by $B$:
#
# $$D^2 - 2\mu_{max} D + \frac{A}{B}\mu_{max} = 0$$
#
# **Step 4:** Solve the quadratic. Recalling $A/B = \mu_{max} S_0/(K_s + S_0)$:
#
# $$D = \mu_{max}\left(1 \pm \sqrt{\frac{K_s}{K_s + S_0}}\right)$$
#
# The $+$ root exceeds $D_{max}$ and is therefore non-physical; taking the $-$ root:
#
# $$D_{opt} = \mu_{max}\left(1 - \sqrt{\frac{K_s}{K_s + S_0}}\right) = 1.7724\,\text{h}^{-1}$$
#
# Both $D_{max}$ and $D_{opt}$ are well below $\mu_{max}$ because $K_s$ and $S_0$ are of comparable magnitude here, meaning the washout boundary is not approached as closely as in systems where $S_0 \gg K_s$.
#
# </div>
